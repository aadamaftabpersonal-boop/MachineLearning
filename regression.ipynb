# %% [markdown]
# example: house price predicition- x axis size in sqft, y axis price
# you train model with right answers and then ask it unknown questions
# x=input variable/feature/input feature
# y=output variable/target variable/label
# m=number of training examples
# (x,y) = single training example
# (x(i), y(i)) = ith training example
