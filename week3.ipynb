# %% [markdown]
# classification problems
# regression models are not good enough
# binary classification - (0/1)
# logistic regression is a binary classification algorithm - fits a curve
# sigmoid function starts at zero and goes to one and is odd symmetric about x=0 - g(z) = 1/(1+e^(-z))
#
# fw,b(x) = P(y=1 | x; w,b) - probability of output =1 given feature x and parameters w and b
# the sigmoid function gives the probability of y being 1
#
# we use a linear model for the sigmoid function
#
# g(wx + b) is sigmoid function, so if wx+b is <0 output is 0, if >0 output is 1
#
# you can have complex sigmoid functions for cluster making
#
# ![image.png](attachment:image.png)
#
# the cost function graph for logistic regression is non-convex  - such a graph has many local minimas
#
# logistic loss function
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# binary cross-entropy loss
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# Loss is a measure of the difference of a single example to its target value while the
# Cost is a measure of the losses over the training set

# %% [markdown]
# overfitting - fits the data too well;  has high variance
# underfitting - doesnt fit the data well, the algorithm has high bias
# goal of machine learning is to find a model that has neither high bias or high variance
#
# classification:
# ![image.png](attachment:image.png)
#
# all features + insufficient data = overfit
# feature selection - choosing relevant features that avoid overfitting, but sometimes in selecting features you may end up leaving out some unnecessary features
#
# regularization - instead of dropping certain features, tuning parameters to suitable values for representing the parameters - avoids large influence of certain not so important parameters and reduces overfitting
#
# addressing overfitting:
# 1. collect more data
# 2. select features
# 3. reduce size of parameters - regularization
#
# the cost function is modified by adding the mean squared errors and the regularization term
#
# ![image-2.png](attachment:image-2.png)
#
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
