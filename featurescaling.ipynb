# %% [markdown]
# for features that take large values the parameter should be small and vice versa
# you can scale down all feature values to a finite workable interval by dividing by maxm
#
# mean normalisation:
# x:= (x-mew)/(max-min)
#
# z-score normalisation:
# z:=(x-mew)/sigma
